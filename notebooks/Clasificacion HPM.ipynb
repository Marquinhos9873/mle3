# %%
import feast
from loguru import logger
import dagshub
import mlflow
import time
import joblib
from datetime import datetime
import uuid
import pandas as pd
from pathlib import Path
from feast import (
    FeatureStore,
    Entity,
    FeatureService,
    FeatureView,
    Field,
    FileSource
)
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from feast.types import Float32, Float64, Int64, String

from reescalador import scaler_process

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.inspection import permutation_importance, PartialDependenceDisplay
from sklearn.model_selection import (GridSearchCV,
                                     RandomizedSearchCV,
                                     train_test_split)
from sklearn.compose import ColumnTransformer
from sklearn.metrics import (classification_report,
                            confusion_matrix,
                            ConfusionMatrixDisplay,
                            accuracy_score)

from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
Stresslevel =  pd.read_csv("../data/Stress_Dataset.csv")
Stress = pd.read_csv('../data/StressLevelDataset.csv')

# %%
Stresslevel['Which type of stress do you primarily experience?'].unique()
Stresslevel.insert(0, 'Id', range(1, len(Stresslevel) + 1))

# %%
Stresslevel['Which type of stress do you primarily experience?'] = Stresslevel['Which type of stress do you primarily experience?'].replace({
    'Eustress (Positive Stress) - Stress that motivates and enhances performance.': 'Eustress',
    'No Stress - Currently experiencing minimal to no stress.': 'No stress',
    'Distress (Negative Stress) - Stress that causes anxiety and impairs well-being.': 'Distress'
})

# %%
Stresslevel
# Out:
#       Id  Gender  Age  Have you recently experienced stress in your life?  \
# 0      1       0   20                                                  3
# 1      2       0   20                                                  2
# 2      3       0   20                                                  5
# 3      4       1   20                                                  3
# 4      5       0   20                                                  3
# ..   ...     ...  ...                                                ...
# 838  839       0   21                                                  3
# 839  840       1   19                                                  3
# 840  841       1   19                                                  4
# 841  842       0   20                                                  5
# 842  843       0   19                                                  4
#
#      Have you noticed a rapid heartbeat or palpitations?  \
# 0                                                    4
# 1                                                    3
# 2                                                    4
# 3                                                    4
# 4                                                    3
# ..                                                 ...
# 838                                                  4
# 839                                                  2
# 840                                                  4
# 841                                                  4
# 842                                                  3
#
#      Have you been dealing with anxiety or tension recently?  \
# 0                                                    2
# 1                                                    2
# 2                                                    2
# 3                                                    3
# 4                                                    3
# ..                                                 ...
# 838                                                  2
# 839                                                  1
# 840                                                  3
# 841                                                  3
# 842                                                  1
#
#      Do you face any sleep problems or difficulties falling asleep?  \
# 0                                                    5
# 1                                                    1
# 2                                                    2
# 3                                                    2
# 4                                                    2
# ..                                                 ...
# 838                                                  3
# 839                                                  2
# 840                                                  4
# 841                                                  4
# 842                                                  3
#
#      Have you been dealing with anxiety or tension recently?.1  \
# 0                                                    1
# 1                                                    1
# 2                                                    1
# 3                                                    2
# 4                                                    2
# ..                                                 ...
# 838                                                  5
# 839                                                  2
# 840                                                  3
# 841                                                  3
# 842                                                  2
#
#      Have you been getting headaches more often than usual?  \
# 0                                                    2
# 1                                                    1
# 2                                                    3
# 3                                                    3
# 4                                                    4
# ..                                                 ...
# 838                                                  1
# 839                                                  1
# 840                                                  2
# 841                                                  4
# 842                                                  1
#
#      Do you get irritated easily?  ...  \
# 0                               1  ...
# 1                               1  ...
# 2                               4  ...
# 3                               4  ...
# 4                               4  ...
# ..                            ...  ...
# 838                             5  ...
# 839                             2  ...
# 840                             2  ...
# 841                             4  ...
# 842                             1  ...
#
#      Are you facing any difficulties with your professors or instructors?  \
# 0                                                    3
# 1                                                    3
# 2                                                    2
# 3                                                    1
# 4                                                    2
# ..                                                 ...
# 838                                                  2
# 839                                                  1
# 840                                                  2
# 841                                                  2
# 842                                                  1
#
#      Is your working environment unpleasant or stressful?  \
# 0                                                    1
# 1                                                    2
# 2                                                    2
# 3                                                    1
# 4                                                    3
# ..                                                 ...
# 838                                                  3
# 839                                                  1
# 840                                                  2
# 841                                                  2
# 842                                                  1
#
#      Do you struggle to find time for relaxation and leisure activities?  \
# 0                                                    4
# 1                                                    1
# 2                                                    2
# 3                                                    2
# 4                                                    1
# ..                                                 ...
# 838                                                  3
# 839                                                  1
# 840                                                  2
# 841                                                  1
# 842                                                  3
#
#      Is your hostel or home environment causing you difficulties?  \
# 0                                                    1
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    2
# ..                                                 ...
# 838                                                  3
# 839                                                  3
# 840                                                  2
# 841                                                  4
# 842                                                  1
#
#      Do you lack confidence in your academic performance?  \
# 0                                                    2
# 1                                                    3
# 2                                                    4
# 3                                                    2
# 4                                                    2
# ..                                                 ...
# 838                                                  4
# 839                                                  2
# 840                                                  3
# 841                                                  3
# 842                                                  1
#
#      Do you lack confidence in your choice of academic subjects?  \
# 0                                                    1
# 1                                                    2
# 2                                                    1
# 3                                                    1
# 4                                                    4
# ..                                                 ...
# 838                                                  1
# 839                                                  1
# 840                                                  1
# 841                                                  5
# 842                                                  2
#
#      Academic and extracurricular activities conflicting for you?  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    2
# ..                                                 ...
# 838                                                  2
# 839                                                  2
# 840                                                  4
# 841                                                  4
# 842                                                  2
#
#      Do you attend classes regularly?  Have you gained/lost weight?  \
# 0                                   1                             2
# 1                                   4                             2
# 2                                   2                             1
# 3                                   5                             3
# 4                                   2                             2
# ..                                ...                           ...
# 838                                 2                             2
# 839                                 3                             1
# 840                                 5                             3
# 841                                 5                             1
# 842                                 5                             4
#
#      Which type of stress do you primarily experience?
# 0                                             Eustress
# 1                                             Eustress
# 2                                             Eustress
# 3                                             Eustress
# 4                                             Eustress
# ..                                                 ...
# 838                                           Eustress
# 839                                          No stress
# 840                                           Eustress
# 841                                           Eustress
# 842                                           Eustress
#
# [843 rows x 27 columns]

# %%
df = Stresslevel
y = df["Which type of stress do you primarily experience?"]
X = df.drop(columns=["Which type of stress do you primarily experience?"])

# Crear promedio de síntomas (todas las preguntas, menos Gender y Age)
symptom_cols = [column for column in X.columns if column not in ["Gender", "Age"]]

#Posible factor psiquis
psiquis_factor = [column for column in X.columns if column in ["Have you recently experienced stress in your life?",
                                                                "Have you been dealing with anxiety or tension recently?",
                                                                "Do you get irritated easily?",
                                                                "Do you have trouble concentrating on your academic tasks?",
                                                               "Do you lack confidence in your academic performance?",
                                                              ]]

#Posible factor biológico
biological_factor = [column for column in X.columns if column in ["Have you noticed a rapid heartbeat or palpitations?",
                                                                  "Do you face any sleep problems or difficulties falling asleep?",
                                                                  "Have you been getting headaches more often than usual?",
                                                                  "Have you gained/lost weight?"                                                                 
                                                                 ]]

#posible factor personal
persona_factor = [column for column in X.columns if column in ["Are you facing any difficulties with your professors or instructors?",
                                                               "Is your working environment unpleasant or stressful?",
                                                               "Do you struggle to find time for relaxation and leisure activities?",
                                                               "Is your hostel or home environment causing you difficulties?",
                                                               "Academic and extracurricular activities conflicting for you?",
                                                               "Do you attend classes regularly?"
                                                              ]]



X["symptom_mean"] = X[symptom_cols].mean(axis = 1)
no_gender_data = X.drop(["Gender", "Id"], axis= 'columns')

cols_copy = [column for column in X.columns if column not in ["Id"]]


reducing_data = X.drop(cols_copy, axis = 'columns')

reducing_data["psicological_feature"] = X[psiquis_factor].mean(axis = 1)
reducing_data["biological_feature"] = X[biological_factor].mean(axis = 1)
reducing_data["personal_feature"] = X[persona_factor].mean(axis = 1)

reducing_data
# Out:
#       Id  psicological_feature  biological_feature  personal_feature
# 0      1                   2.0                3.25          2.166667
# 1      2                   2.4                1.75          2.000000
# 2      3                   3.4                2.50          1.666667
# 3      4                   3.0                3.00          1.833333
# 4      5                   3.2                2.75          2.000000
# ..   ...                   ...                 ...               ...
# 838  839                   3.6                2.50          2.500000
# 839  840                   2.2                1.50          1.833333
# 840  841                   3.0                3.25          2.833333
# 841  842                   3.8                3.25          3.000000
# 842  843                   2.2                2.75          2.166667
#
# [843 rows x 4 columns]

# %%
reducing_data.rename(columns={"Id": "Id_user_data"}, inplace=True)

# %%
reducing_data
# Out:
#      Id_user_data  psicological_feature  biological_feature  personal_feature
# 0               1                   2.0                3.25          2.166667
# 1               2                   2.4                1.75          2.000000
# 2               3                   3.4                2.50          1.666667
# 3               4                   3.0                3.00          1.833333
# 4               5                   3.2                2.75          2.000000
# ..            ...                   ...                 ...               ...
# 838           839                   3.6                2.50          2.500000
# 839           840                   2.2                1.50          1.833333
# 840           841                   3.0                3.25          2.833333
# 841           842                   3.8                3.25          3.000000
# 842           843                   2.2                2.75          2.166667
#
# [843 rows x 4 columns]

# %% [markdown]
# ### FEATURE STORE

# %%
class Feast_use():
    def __init__(self, filepath, external_data=None):
        self.filepath = filepath
        self.feature_table = None
        self.external_data = external_data

        
    def table_creator(self, feature_table=None, external_data=None):

       
        if feature_table is None or feature_table.empty:
            feature_table = pd.DataFrame()
        
        self.feature_table = feature_table

        # → Mantengo tu lógica
        self.feature_table['UId'] = [str(uuid.uuid4()) for _ in range(self.feature_table.shape[0])]
        self.feature_table["created"] = [datetime.now() for _ in range(self.feature_table.shape[0])]
        logger.info(f"Feature Table creada -> {datetime.now()}")

       
        if external_data is not None:
            self.feature_table = pd.concat(
                [
                    self.feature_table.reset_index(drop=True),
                    external_data.reset_index(drop=True)
                ],
                axis=1
            )

        return self.feature_table


    def write_feature_table(self, filepath: str) -> None:
        if self.feature_table is not None and not self.feature_table.empty:
            self.feature_table.to_parquet(f"{filepath}.parquet", index=False)
            self.feature_table.to_csv(f"{filepath}.csv", index=False)
        else:
            raise Exception("La feature table no ha sido creada.")


f = Feast_use(filepath= '~/Feature_Store_3/valued_pup/feature_repo/')
feature_table_new = f.table_creator(external_data=reducing_data)
logger.info("Guardando feature table")
f.write_feature_table(filepath='~/Feature_Store_3/valued_pup/feature_repo/')
# Out:
# 2025-11-16 22:34:10.593 | INFO     | __main__:table_creator:19 - Feature Table creada -> 2025-11-16 22:34:10.593857
# 2025-11-16 22:34:10.603 | INFO     | __main__:<module>:44 - Guardando feature table
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[11], line 45
#      43 feature_table_new = f.table_creator(external_data=reducing_data)
#      44 logger.info("Guardando feature table")
# ---> 45 f.write_feature_table(filepath='~/Feature_Store_3/valued_pup/feature_repo/')
#
# Cell In[11], line 36, in Feast_use.write_feature_table(self, filepath)
#      34 def write_feature_table(self, filepath: str) -> None:
#      35     if self.feature_table is not None and not self.feature_table.empty:
# ---> 36         self.feature_table.to_parquet(f"{filepath}.parquet", index=False)
#      37         self.feature_table.to_csv(f"{filepath}.csv", index=False)
#      38     else:
#
# File ~/mle2/.venv/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/mle2/.venv/lib/python3.12/site-packages/pandas/core/frame.py:3124, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3043 """
#    3044 Write a DataFrame to the binary parquet format.
#    3045
#    (...)   3120 >>> content = f.read()
#    3121 """
#    3122 from pandas.io.parquet import to_parquet
# -> 3124 return to_parquet(
#    3125     self,
#    3126     path,
#    3127     engine,
#    3128     compression=compression,
#    3129     index=index,
#    3130     partition_cols=partition_cols,
#    3131     storage_options=storage_options,
#    3132     **kwargs,
#    3133 )
#
# File ~/mle2/.venv/lib/python3.12/site-packages/pandas/io/parquet.py:482, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     478 impl = get_engine(engine)
#     480 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 482 impl.write(
#     483     df,
#     484     path_or_buf,
#     485     compression=compression,
#     486     index=index,
#     487     partition_cols=partition_cols,
#     488     storage_options=storage_options,
#     489     filesystem=filesystem,
#     490     **kwargs,
#     491 )
#     493 if path is None:
#     494     assert isinstance(path_or_buf, io.BytesIO)
#
# File ~/mle2/.venv/lib/python3.12/site-packages/pandas/io/parquet.py:199, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     196     merged_metadata = {**existing_metadata, **df_metadata}
#     197     table = table.replace_schema_metadata(merged_metadata)
# --> 199 path_or_handle, handles, filesystem = _get_path_or_handle(
#     200     path,
#     201     filesystem,
#     202     storage_options=storage_options,
#     203     mode="wb",
#     204     is_dir=partition_cols is not None,
#     205 )
#     206 if (
#     207     isinstance(path_or_handle, io.BufferedWriter)
#     208     and hasattr(path_or_handle, "name")
#     209     and isinstance(path_or_handle.name, (str, bytes))
#     210 ):
#     211     if isinstance(path_or_handle.name, bytes):
#
# File ~/mle2/.venv/lib/python3.12/site-packages/pandas/io/parquet.py:141, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     131 handles = None
#     132 if (
#     133     not fs
#     134     and not is_dir
#    (...)    139     # fsspec resources can also point to directories
#     140     # this branch is used for example when reading from non-fsspec URLs
# --> 141     handles = get_handle(
#     142         path_or_handle, mode, is_text=False, storage_options=storage_options
#     143     )
#     144     fs = None
#     145     path_or_handle = handles.handle
#
# File ~/mle2/.venv/lib/python3.12/site-packages/pandas/io/common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~/mle2/.venv/lib/python3.12/site-packages/pandas/io/common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '/home/marcoloq/Feature_Store_3/valued_pup/feature_repo'

# %% [markdown]
# ### Feast no feastea dx

# %%
mlflow.set_tracking_uri('https://dagshub.com/Marquinhos9873/mle3.mlflow')
mlflow.set_experiment("StressLevel_DSRP_mle3")
mlflow.create_experiment("StressLevel_DSRP_mle3")
# Out:
# 2025/11/16 22:51:09 INFO mlflow.tracking.fluent: Experiment with name 'StressLevel_DSRP_mle3' does not exist. Creating a new experiment.
# ---------------------------------------------------------------------------
# RestException                             Traceback (most recent call last)
# Cell In[46], line 3
#       1 mlflow.set_tracking_uri('https://dagshub.com/Marquinhos9873/mle3.mlflow')
#       2 mlflow.set_experiment("StressLevel_DSRP_mle3")
# ----> 3 mlflow.create_experiment("StressLevel_DSRP_mle3")
#
# File ~/mle2/.venv/lib/python3.12/site-packages/mlflow/tracking/fluent.py:2065, in create_experiment(name, artifact_location, tags)
#    2017 def create_experiment(
#    2018     name: str,
#    2019     artifact_location: Optional[str] = None,
#    2020     tags: Optional[dict[str, Any]] = None,
#    2021 ) -> str:
#    2022     """
#    2023     Create an experiment.
#    2024
#    (...)   2063         Creation timestamp: 1662004217511
#    2064     """
# -> 2065     return MlflowClient().create_experiment(name, artifact_location, tags)
#
# File ~/mle2/.venv/lib/python3.12/site-packages/mlflow/tracking/client.py:1704, in MlflowClient.create_experiment(self, name, artifact_location, tags)
#    1652 def create_experiment(
#    1653     self,
#    1654     name: str,
#    1655     artifact_location: Optional[str] = None,
#    1656     tags: Optional[dict[str, Any]] = None,
#    1657 ) -> str:
#    1658     """Create an experiment.
#    1659
#    1660     Args:
#    (...)   1702
#    1703     """
# -> 1704     return self._tracking_client.create_experiment(name, artifact_location, tags)
#
# File ~/mle2/.venv/lib/python3.12/site-packages/mlflow/tracking/_tracking_service/client.py:275, in TrackingServiceClient.create_experiment(self, name, artifact_location, tags)
#     261 """Create an experiment.
#     262
#     263 Args:
#    (...)    272
#     273 """
#     274 _validate_experiment_artifact_location(artifact_location)
# --> 275 return self.store.create_experiment(
#     276     name=name,
#     277     artifact_location=artifact_location,
#     278     tags=[ExperimentTag(key, value) for (key, value) in tags.items()] if tags else [],
#     279 )
#
# File ~/mle2/.venv/lib/python3.12/site-packages/mlflow/store/tracking/rest_store.py:185, in RestStore.create_experiment(self, name, artifact_location, tags)
#     181 tag_protos = [tag.to_proto() for tag in tags] if tags else []
#     182 req_body = message_to_json(
#     183     CreateExperiment(name=name, artifact_location=artifact_location, tags=tag_protos)
#     184 )
# --> 185 response_proto = self._call_endpoint(CreateExperiment, req_body)
#     186 return response_proto.experiment_id
#
# File ~/mle2/.venv/lib/python3.12/site-packages/mlflow/store/tracking/rest_store.py:134, in RestStore._call_endpoint(self, api, json_body, endpoint, retry_timeout_seconds)
#     132     endpoint, method = _METHOD_TO_INFO[api]
#     133 response_proto = api.Response()
# --> 134 return call_endpoint(
#     135     self.get_host_creds(),
#     136     endpoint,
#     137     method,
#     138     json_body,
#     139     response_proto,
#     140     retry_timeout_seconds=retry_timeout_seconds,
#     141 )
#
# File ~/mle2/.venv/lib/python3.12/site-packages/mlflow/utils/rest_utils.py:590, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers, retry_timeout_seconds)
#     587     call_kwargs["json"] = json_body
#     588     response = http_request(**call_kwargs)
# --> 590 response = verify_rest_response(response, endpoint)
#     591 response_to_parse = response.text
#     592 try:
#
# File ~/mle2/.venv/lib/python3.12/site-packages/mlflow/utils/rest_utils.py:304, in verify_rest_response(response, endpoint)
#     302 if response.status_code != 200:
#     303     if _can_parse_as_json_object(response.text):
# --> 304         raise RestException(json.loads(response.text))
#     305     else:
#     306         base_msg = (
#     307             f"API request to endpoint {endpoint} "
#     308             f"failed with error code {response.status_code} != 200"
#     309         )
#
# RestException: BAD_REQUEST: Response: {'error_code': 'BAD_REQUEST'}

# %%
params={"Decision Tree": {
                        "criterion": ['gini','log_loss'],
                        "max_depth": [0, 10, 12, 16],
                        "min_samples_split": [2, 3, 4, 5]
                    },
    
                     "Random Forest":{
                        "n_estimators" : [110 , 115, 125, 130],
                        "criterion" : ['gini' ,'log_loss', 'entropy'],
                        "max_depth" : [None, 5, 7 , 8]
                    },
    
                    "Gradient Boosting": {
                        "n_estimators" : [110 , 115, 125, 130],
                        "max_depth" : [None, 5, 7 , 8],
                        "learning_rate": [0.0045 , 0.01, 0.05, 0.10],
                        "min_samples_split": [2, 3, 4, 5],
                    },
                    "XGBClassifier":{
                        'learning_rate':[0.0045 , 0.01, 0.05, 0.10],
                        'max_depth': [5, 6, 7],
                        'n_estimators': [256, 128, 64, 12],
                        'tree_method': ['auto', 'approx']
                    },
    
                    "CatBoosting Classifier":{
                        'iterations': [200, 400, 800],
                        'learning_rate': [0.001, 0.01, 0.05, 0.1],
                        'depth': [3, 4, 6, 8, 10],
                        'l2_leaf_reg': [1, 3, 5, 7, 9],
                        'bootstrap_type': ['Bayesian', 'Bernoulli', 'MVS']
                    }
                    
                }

# %%
xgb = XGBClassifier(device= 'cuda', verbosity = 1)

# %%
kitty = CatBoostClassifier(task_type = 'GPU', devices = '0', early_stopping_rounds = 100)

# %%
Forest = RandomForestClassifier(verbose = 1)

# %%
Grades = GradientBoostingClassifier(verbose = 1)

# %%
X, y
# Out:
# (      Id  Gender  Age  Have you recently experienced stress in your life?  \
#  0      1       0   20                                                  3
#  1      2       0   20                                                  2
#  2      3       0   20                                                  5
#  3      4       1   20                                                  3
#  4      5       0   20                                                  3
#  ..   ...     ...  ...                                                ...
#  838  839       0   21                                                  3
#  839  840       1   19                                                  3
#  840  841       1   19                                                  4
#  841  842       0   20                                                  5
#  842  843       0   19                                                  4
#
#       Have you noticed a rapid heartbeat or palpitations?  \
#  0                                                    4
#  1                                                    3
#  2                                                    4
#  3                                                    4
#  4                                                    3
#  ..                                                 ...
#  838                                                  4
#  839                                                  2
#  840                                                  4
#  841                                                  4
#  842                                                  3
#
#       Have you been dealing with anxiety or tension recently?  \
#  0                                                    2
#  1                                                    2
#  2                                                    2
#  3                                                    3
#  4                                                    3
#  ..                                                 ...
#  838                                                  2
#  839                                                  1
#  840                                                  3
#  841                                                  3
#  842                                                  1
#
#       Do you face any sleep problems or difficulties falling asleep?  \
#  0                                                    5
#  1                                                    1
#  2                                                    2
#  3                                                    2
#  4                                                    2
#  ..                                                 ...
#  838                                                  3
#  839                                                  2
#  840                                                  4
#  841                                                  4
#  842                                                  3
#
#       Have you been dealing with anxiety or tension recently?.1  \
#  0                                                    1
#  1                                                    1
#  2                                                    1
#  3                                                    2
#  4                                                    2
#  ..                                                 ...
#  838                                                  5
#  839                                                  2
#  840                                                  3
#  841                                                  3
#  842                                                  2
#
#       Have you been getting headaches more often than usual?  \
#  0                                                    2
#  1                                                    1
#  2                                                    3
#  3                                                    3
#  4                                                    4
#  ..                                                 ...
#  838                                                  1
#  839                                                  1
#  840                                                  2
#  841                                                  4
#  842                                                  1
#
#       Do you get irritated easily?  ...  \
#  0                               1  ...
#  1                               1  ...
#  2                               4  ...
#  3                               4  ...
#  4                               4  ...
#  ..                            ...  ...
#  838                             5  ...
#  839                             2  ...
#  840                             2  ...
#  841                             4  ...
#  842                             1  ...
#
#       Are you facing any difficulties with your professors or instructors?  \
#  0                                                    3
#  1                                                    3
#  2                                                    2
#  3                                                    1
#  4                                                    2
#  ..                                                 ...
#  838                                                  2
#  839                                                  1
#  840                                                  2
#  841                                                  2
#  842                                                  1
#
#       Is your working environment unpleasant or stressful?  \
#  0                                                    1
#  1                                                    2
#  2                                                    2
#  3                                                    1
#  4                                                    3
#  ..                                                 ...
#  838                                                  3
#  839                                                  1
#  840                                                  2
#  841                                                  2
#  842                                                  1
#
#       Do you struggle to find time for relaxation and leisure activities?  \
#  0                                                    4
#  1                                                    1
#  2                                                    2
#  3                                                    2
#  4                                                    1
#  ..                                                 ...
#  838                                                  3
#  839                                                  1
#  840                                                  2
#  841                                                  1
#  842                                                  3
#
#       Is your hostel or home environment causing you difficulties?  \
#  0                                                    1
#  1                                                    1
#  2                                                    1
#  3                                                    1
#  4                                                    2
#  ..                                                 ...
#  838                                                  3
#  839                                                  3
#  840                                                  2
#  841                                                  4
#  842                                                  1
#
#       Do you lack confidence in your academic performance?  \
#  0                                                    2
#  1                                                    3
#  2                                                    4
#  3                                                    2
#  4                                                    2
#  ..                                                 ...
#  838                                                  4
#  839                                                  2
#  840                                                  3
#  841                                                  3
#  842                                                  1
#
#       Do you lack confidence in your choice of academic subjects?  \
#  0                                                    1
#  1                                                    2
#  2                                                    1
#  3                                                    1
#  4                                                    4
#  ..                                                 ...
#  838                                                  1
#  839                                                  1
#  840                                                  1
#  841                                                  5
#  842                                                  2
#
#       Academic and extracurricular activities conflicting for you?  \
#  0                                                    3
#  1                                                    1
#  2                                                    1
#  3                                                    1
#  4                                                    2
#  ..                                                 ...
#  838                                                  2
#  839                                                  2
#  840                                                  4
#  841                                                  4
#  842                                                  2
#
#       Do you attend classes regularly?  Have you gained/lost weight?  \
#  0                                   1                             2
#  1                                   4                             2
#  2                                   2                             1
#  3                                   5                             3
#  4                                   2                             2
#  ..                                ...                           ...
#  838                                 2                             2
#  839                                 3                             1
#  840                                 5                             3
#  841                                 5                             1
#  842                                 5                             4
#
#       symptom_mean
#  0        2.208333
#  1        2.000000
#  2        2.541667
#  3        2.583333
#  4        2.500000
#  ..            ...
#  838     37.666667
#  839     36.750000
#  840     37.583333
#  841     38.125000
#  842     37.333333
#
#  [843 rows x 27 columns],
#  0       Eustress
#  1       Eustress
#  2       Eustress
#  3       Eustress
#  4       Eustress
#           ...
#  838     Eustress
#  839    No stress
#  840     Eustress
#  841     Eustress
#  842     Eustress
#  Name: Which type of stress do you primarily experience?, Length: 843, dtype: object)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size= 0.255)
logger.info("Datos divididos en train y test")
logger.info(f"Datos de train: {X_train.shape}")
logger.info(f"Datos de test: {X_test.shape}")
logger.info(f"Datos de train: {y_train.shape}")
logger.info(f"Datos de test: {y_test.shape}")
# Out:
# 2025-11-16 22:34:50.068 | INFO     | __main__:<module>:2 - Datos divididos en train y test
# 2025-11-16 22:34:50.070 | INFO     | __main__:<module>:3 - Datos de train: (628, 27)
# 2025-11-16 22:34:50.072 | INFO     | __main__:<module>:4 - Datos de test: (215, 27)
# 2025-11-16 22:34:50.073 | INFO     | __main__:<module>:5 - Datos de train: (628,)
# 2025-11-16 22:34:50.074 | INFO     | __main__:<module>:6 - Datos de test: (215,)

# %%
#StressLevel
rescaled_StressLevel = scaler_process(
    data= X,
    scale_method=StandardScaler(),
    pipeline_name='PrimeiroPipeline'
)

pipeline, metadata = rescaled_StressLevel.run_scaler()
variance_plot = rescaled_StressLevel.plot_variance()
mlflow.log_artifact(variance_plot)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 10
#       8 pipeline, metadata = rescaled_StressLevel.run_scaler()
#       9 variance_plot = rescaled_StressLevel.plot_variance()
# ---> 10 mlflow.log_artifact(variance_plot)
#
# File ~/mle2/.venv/lib/python3.12/site-packages/mlflow/tracking/fluent.py:1403, in log_artifact(local_path, artifact_path, run_id)
#    1373 """
#    1374 Log a local file or directory as an artifact of the currently active run. If no run is
#    1375 active, this method will create a new active run.
#    (...)   1400             mlflow.log_artifact(path)
#    1401 """
#    1402 run_id = run_id or _get_or_start_run().info.run_id
# -> 1403 MlflowClient().log_artifact(run_id, local_path, artifact_path)
#
# File ~/mle2/.venv/lib/python3.12/site-packages/mlflow/tracking/client.py:2351, in MlflowClient.log_artifact(self, run_id, local_path, artifact_path)
#    2347 if run_id.startswith(TRACE_REQUEST_ID_PREFIX):
#    2348     raise MlflowException(
#    2349         f"Invalid run id: {run_id}. `log_artifact` run id must map to a valid run."
#    2350     )
# -> 2351 self._tracking_client.log_artifact(run_id, local_path, artifact_path)
#
# File ~/mle2/.venv/lib/python3.12/site-packages/mlflow/tracking/_tracking_service/client.py:632, in TrackingServiceClient.log_artifact(self, run_id, local_path, artifact_path)
#     623 """
#     624 Write a local file or directory to the remote ``artifact_uri``.
#     625
#    (...)    629     artifact_path: If provided, the directory in ``artifact_uri`` to write to.
#     630 """
#     631 artifact_repo = self._get_artifact_repo(run_id)
# --> 632 if os.path.isdir(local_path):
#     633     dir_name = os.path.basename(os.path.normpath(local_path))
#     634     path_name = (
#     635         os.path.join(artifact_path, dir_name) if artifact_path is not None else dir_name
#     636     )
#
# File <frozen genericpath>:42, in isdir(s)
#
# TypeError: stat: path should be string, bytes, os.PathLike or integer, not NoneType

# %%
mlflow.end_run()

# %%
xgb = XGBClassifier(device= 'cuda', verbosity = 1)

# %%
kitty = CatBoostClassifier(task_type = 'GPU', devices = '0', early_stopping_rounds = 100)

# %%
Forest = RandomForestClassifier(verbose = 1)

# %%
Grades = GradientBoostingClassifier(verbose = 1)

# %%
Stress.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   anxiety_level                 1100 non-null   int64
#  1   self_esteem                   1100 non-null   int64
#  2   mental_health_history         1100 non-null   int64
#  3   depression                    1100 non-null   int64
#  4   headache                      1100 non-null   int64
#  5   blood_pressure                1100 non-null   int64
#  6   sleep_quality                 1100 non-null   int64
#  7   breathing_problem             1100 non-null   int64
#  8   noise_level                   1100 non-null   int64
#  9   living_conditions             1100 non-null   int64
#  10  safety                        1100 non-null   int64
#  11  basic_needs                   1100 non-null   int64
#  12  academic_performance          1100 non-null   int64
#  13  study_load                    1100 non-null   int64
#  14  teacher_student_relationship  1100 non-null   int64
#  15  future_career_concerns        1100 non-null   int64
#  16  social_support                1100 non-null   int64
#  17  peer_pressure                 1100 non-null   int64
#  18  extracurricular_activities    1100 non-null   int64
#  19  bullying                      1100 non-null   int64
#  20  stress_level                  1100 non-null   int64
# dtypes: int64(21)
# memory usage: 180.6 KB

# %%
X = Stress.drop(columns=["stress_level"])
y = Stress["stress_level"]

# %%
X, y
# Out:
# (      anxiety_level  self_esteem  mental_health_history  depression  headache  \
#  0                14           20                      0          11         2
#  1                15            8                      1          15         5
#  2                12           18                      1          14         2
#  3                16           12                      1          15         4
#  4                16           28                      0           7         2
#  ...             ...          ...                    ...         ...       ...
#  1095             11           17                      0          14         3
#  1096              9           12                      0           8         0
#  1097              4           26                      0           3         1
#  1098             21            0                      1          19         5
#  1099             18            6                      1          15         3
#
#        blood_pressure  sleep_quality  breathing_problem  noise_level  \
#  0                  1              2                  4            2
#  1                  3              1                  4            3
#  2                  1              2                  2            2
#  3                  3              1                  3            4
#  4                  3              5                  1            3
#  ...              ...            ...                ...          ...
#  1095               1              3                  2            2
#  1096               3              0                  0            0
#  1097               2              5                  2            2
#  1098               3              1                  4            3
#  1099               3              0                  3            3
#
#        living_conditions  safety  basic_needs  academic_performance  \
#  0                     3       3            2                     3
#  1                     1       2            2                     1
#  2                     2       3            2                     2
#  3                     2       2            2                     2
#  4                     2       4            3                     4
#  ...                 ...     ...          ...                   ...
#  1095                  2       2            3                     2
#  1096                  1       3            4                     0
#  1097                  3       4            4                     5
#  1098                  1       1            1                     2
#  1099                  0       4            3                     3
#
#        study_load  teacher_student_relationship  future_career_concerns  \
#  0              2                             3                       3
#  1              4                             1                       5
#  2              3                             3                       2
#  3              4                             1                       4
#  4              3                             1                       2
#  ...          ...                           ...                     ...
#  1095           2                             2                       3
#  1096           1                             1                       1
#  1097           1                             4                       1
#  1098           5                             1                       4
#  1099           4                             3                       3
#
#        social_support  peer_pressure  extracurricular_activities  bullying
#  0                  2              3                           3         2
#  1                  1              4                           5         5
#  2                  2              3                           2         2
#  3                  1              4                           4         5
#  4                  1              5                           0         5
#  ...              ...            ...                         ...       ...
#  1095               3              2                           3         3
#  1096               1              3                           4         3
#  1097               3              1                           2         1
#  1098               1              4                           4         4
#  1099               1              5                           1         4
#
#  [1100 rows x 20 columns],
#  0       1
#  1       2
#  2       1
#  3       2
#  4       1
#         ..
#  1095    1
#  1096    2
#  1097    0
#  1098    2
#  1099    2
#  Name: stress_level, Length: 1100, dtype: int64)

# %%
xgb = XGBClassifier(device= 'cuda', )

# %%
kitty = CatBoostClassifier()

# %%
Grades = GradientBoostingClassifier()

# %%
Forest = RandomForestClassifier()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size= 0.255)
logger.info("Datos divididos en train y test")
logger.info(f"Datos de train: {X_train.shape}")
logger.info(f"Datos de test: {X_test.shape}")
logger.info(f"Datos de train: {y_train.shape}")
logger.info(f"Datos de test: {y_test.shape}")
# Out:
# 2025-11-16 22:42:11.613 | INFO     | __main__:<module>:2 - Datos divididos en train y test
# 2025-11-16 22:42:11.614 | INFO     | __main__:<module>:3 - Datos de train: (819, 20)
# 2025-11-16 22:42:11.618 | INFO     | __main__:<module>:4 - Datos de test: (281, 20)
# 2025-11-16 22:42:11.619 | INFO     | __main__:<module>:5 - Datos de train: (819,)
# 2025-11-16 22:42:11.620 | INFO     | __main__:<module>:6 - Datos de test: (281,)

# %%
#Stress
rescaled_Stress = scaler_process(
    data= X,
    scale_method=StandardScaler(),
    pipeline_name='PrimeiroPipeline'
)

pipeline, metadata = rescaled_Stress.run_scaler()
rescaled_Stress.plot_variance()

# %% [markdown]
# ### Hp ops

# %% [markdown]
# ![image.png](attachment:76a9ffe8-f982-4a32-bbbb-f5be30d7e8e4.png)
