# %%
import feast
import os
from loguru import logger
import dagshub
import mlflow
import time
import joblib
from datetime import datetime
import uuid
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from feast import (
    FeatureStore,
    Entity,
    FeatureService,
    FeatureView,
    Field,
    FileSource
)
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from feast.types import Float32, Float64, Int64, String

import reescalador

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.inspection import permutation_importance, PartialDependenceDisplay
from sklearn.model_selection import (GridSearchCV,
                                     RandomizedSearchCV,
                                     train_test_split)
from sklearn.compose import ColumnTransformer
from sklearn.metrics import (classification_report,
                            confusion_matrix,
                            ConfusionMatrixDisplay,
                            accuracy_score)

from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier


dagshub.init(repo_owner='Marquinhos9873', repo_name='mle3', mlflow=True)
# Out:
# Accessing as Marquinhos9873
# Initialized MLflow to track repo "Marquinhos9873/mle3"
# Repository Marquinhos9873/mle3 initialized!

# %%
Stresslevel =  pd.read_csv("../data/Stress_Dataset.csv")
Stress = pd.read_csv('../data/StressLevelDataset.csv')

# %%
Stresslevel['Which type of stress do you primarily experience?'].unique()
Stresslevel.insert(0, 'Id', range(1, len(Stresslevel) + 1))

# %%
Stresslevel['Which type of stress do you primarily experience?'] = Stresslevel['Which type of stress do you primarily experience?'].replace({
    'Eustress (Positive Stress) - Stress that motivates and enhances performance.': 2,
    'No Stress - Currently experiencing minimal to no stress.': 1,
    'Distress (Negative Stress) - Stress that causes anxiety and impairs well-being.': 0
})
# Out:
# /tmp/ipykernel_2941/3091548565.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Stresslevel['Which type of stress do you primarily experience?'] = Stresslevel['Which type of stress do you primarily experience?'].replace({

# %%
Stresslevel['Which type of stress do you primarily experience?'] = Stresslevel['Which type of stress do you primarily experience?'].astype(int)
Stresslevel
# Out:
#       Id  Gender  Age  Have you recently experienced stress in your life?  \
# 0      1       0   20                                                  3
# 1      2       0   20                                                  2
# 2      3       0   20                                                  5
# 3      4       1   20                                                  3
# 4      5       0   20                                                  3
# ..   ...     ...  ...                                                ...
# 838  839       0   21                                                  3
# 839  840       1   19                                                  3
# 840  841       1   19                                                  4
# 841  842       0   20                                                  5
# 842  843       0   19                                                  4
#
#      Have you noticed a rapid heartbeat or palpitations?  \
# 0                                                    4
# 1                                                    3
# 2                                                    4
# 3                                                    4
# 4                                                    3
# ..                                                 ...
# 838                                                  4
# 839                                                  2
# 840                                                  4
# 841                                                  4
# 842                                                  3
#
#      Have you been dealing with anxiety or tension recently?  \
# 0                                                    2
# 1                                                    2
# 2                                                    2
# 3                                                    3
# 4                                                    3
# ..                                                 ...
# 838                                                  2
# 839                                                  1
# 840                                                  3
# 841                                                  3
# 842                                                  1
#
#      Do you face any sleep problems or difficulties falling asleep?  \
# 0                                                    5
# 1                                                    1
# 2                                                    2
# 3                                                    2
# 4                                                    2
# ..                                                 ...
# 838                                                  3
# 839                                                  2
# 840                                                  4
# 841                                                  4
# 842                                                  3
#
#      Have you been dealing with anxiety or tension recently?.1  \
# 0                                                    1
# 1                                                    1
# 2                                                    1
# 3                                                    2
# 4                                                    2
# ..                                                 ...
# 838                                                  5
# 839                                                  2
# 840                                                  3
# 841                                                  3
# 842                                                  2
#
#      Have you been getting headaches more often than usual?  \
# 0                                                    2
# 1                                                    1
# 2                                                    3
# 3                                                    3
# 4                                                    4
# ..                                                 ...
# 838                                                  1
# 839                                                  1
# 840                                                  2
# 841                                                  4
# 842                                                  1
#
#      Do you get irritated easily?  ...  \
# 0                               1  ...
# 1                               1  ...
# 2                               4  ...
# 3                               4  ...
# 4                               4  ...
# ..                            ...  ...
# 838                             5  ...
# 839                             2  ...
# 840                             2  ...
# 841                             4  ...
# 842                             1  ...
#
#      Are you facing any difficulties with your professors or instructors?  \
# 0                                                    3
# 1                                                    3
# 2                                                    2
# 3                                                    1
# 4                                                    2
# ..                                                 ...
# 838                                                  2
# 839                                                  1
# 840                                                  2
# 841                                                  2
# 842                                                  1
#
#      Is your working environment unpleasant or stressful?  \
# 0                                                    1
# 1                                                    2
# 2                                                    2
# 3                                                    1
# 4                                                    3
# ..                                                 ...
# 838                                                  3
# 839                                                  1
# 840                                                  2
# 841                                                  2
# 842                                                  1
#
#      Do you struggle to find time for relaxation and leisure activities?  \
# 0                                                    4
# 1                                                    1
# 2                                                    2
# 3                                                    2
# 4                                                    1
# ..                                                 ...
# 838                                                  3
# 839                                                  1
# 840                                                  2
# 841                                                  1
# 842                                                  3
#
#      Is your hostel or home environment causing you difficulties?  \
# 0                                                    1
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    2
# ..                                                 ...
# 838                                                  3
# 839                                                  3
# 840                                                  2
# 841                                                  4
# 842                                                  1
#
#      Do you lack confidence in your academic performance?  \
# 0                                                    2
# 1                                                    3
# 2                                                    4
# 3                                                    2
# 4                                                    2
# ..                                                 ...
# 838                                                  4
# 839                                                  2
# 840                                                  3
# 841                                                  3
# 842                                                  1
#
#      Do you lack confidence in your choice of academic subjects?  \
# 0                                                    1
# 1                                                    2
# 2                                                    1
# 3                                                    1
# 4                                                    4
# ..                                                 ...
# 838                                                  1
# 839                                                  1
# 840                                                  1
# 841                                                  5
# 842                                                  2
#
#      Academic and extracurricular activities conflicting for you?  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    2
# ..                                                 ...
# 838                                                  2
# 839                                                  2
# 840                                                  4
# 841                                                  4
# 842                                                  2
#
#      Do you attend classes regularly?  Have you gained/lost weight?  \
# 0                                   1                             2
# 1                                   4                             2
# 2                                   2                             1
# 3                                   5                             3
# 4                                   2                             2
# ..                                ...                           ...
# 838                                 2                             2
# 839                                 3                             1
# 840                                 5                             3
# 841                                 5                             1
# 842                                 5                             4
#
#      Which type of stress do you primarily experience?
# 0                                                    2
# 1                                                    2
# 2                                                    2
# 3                                                    2
# 4                                                    2
# ..                                                 ...
# 838                                                  2
# 839                                                  1
# 840                                                  2
# 841                                                  2
# 842                                                  2
#
# [843 rows x 27 columns]

# %%
df = Stresslevel
y = df["Which type of stress do you primarily experience?"]
X = df.drop(columns=["Which type of stress do you primarily experience?"])

# Crear promedio de síntomas (todas las preguntas, menos Gender y Age)
symptom_cols = [column for column in X.columns if column not in ["Gender", "Age"]]

#Posible factor psiquis
psiquis_factor = [column for column in X.columns if column in ["Have you recently experienced stress in your life?",
                                                                "Have you been dealing with anxiety or tension recently?",
                                                                "Do you get irritated easily?",
                                                                "Do you have trouble concentrating on your academic tasks?",
                                                               "Do you lack confidence in your academic performance?",
                                                              ]]

#Posible factor biológico
biological_factor = [column for column in X.columns if column in ["Have you noticed a rapid heartbeat or palpitations?",
                                                                  "Do you face any sleep problems or difficulties falling asleep?",
                                                                  "Have you been getting headaches more often than usual?",
                                                                  "Have you gained/lost weight?"                                                                 
                                                                 ]]

#posible factor personal
persona_factor = [column for column in X.columns if column in ["Are you facing any difficulties with your professors or instructors?",
                                                               "Is your working environment unpleasant or stressful?",
                                                               "Do you struggle to find time for relaxation and leisure activities?",
                                                               "Is your hostel or home environment causing you difficulties?",
                                                               "Academic and extracurricular activities conflicting for you?",
                                                               "Do you attend classes regularly?"
                                                              ]]



X["symptom_mean"] = X[symptom_cols].mean(axis = 1)
no_gender_data = X.drop(["Gender", "Id"], axis= 'columns')

cols_copy = [column for column in X.columns if column not in ["Id"]]


reducing_data = X.drop(cols_copy, axis = 'columns')

reducing_data["psicological_feature"] = X[psiquis_factor].mean(axis = 1)
reducing_data["biological_feature"] = X[biological_factor].mean(axis = 1)
reducing_data["personal_feature"] = X[persona_factor].mean(axis = 1)

reducing_data
# Out:
#       Id  psicological_feature  biological_feature  personal_feature
# 0      1                   2.0                3.25          2.166667
# 1      2                   2.4                1.75          2.000000
# 2      3                   3.4                2.50          1.666667
# 3      4                   3.0                3.00          1.833333
# 4      5                   3.2                2.75          2.000000
# ..   ...                   ...                 ...               ...
# 838  839                   3.6                2.50          2.500000
# 839  840                   2.2                1.50          1.833333
# 840  841                   3.0                3.25          2.833333
# 841  842                   3.8                3.25          3.000000
# 842  843                   2.2                2.75          2.166667
#
# [843 rows x 4 columns]

# %%
reducing_data.rename(columns={"Id": "Id_user_data"}, inplace=True)

# %%
reducing_data
# Out:
#      Id_user_data  psicological_feature  biological_feature  personal_feature
# 0               1                   2.0                3.25          2.166667
# 1               2                   2.4                1.75          2.000000
# 2               3                   3.4                2.50          1.666667
# 3               4                   3.0                3.00          1.833333
# 4               5                   3.2                2.75          2.000000
# ..            ...                   ...                 ...               ...
# 838           839                   3.6                2.50          2.500000
# 839           840                   2.2                1.50          1.833333
# 840           841                   3.0                3.25          2.833333
# 841           842                   3.8                3.25          3.000000
# 842           843                   2.2                2.75          2.166667
#
# [843 rows x 4 columns]

# %% [markdown]
# ### FEATURE STORE

# %%
class Feast_use():
    def __init__(self, filepath, external_data=None):
        self.filepath = filepath
        self.feature_table = None
        self.external_data = external_data

        
    def table_creator(self, feature_table=None, external_data=None):

       
        if feature_table is None or feature_table.empty:
            feature_table = pd.DataFrame()
        
        self.feature_table = feature_table

        
        self.feature_table['UId'] = [str(uuid.uuid4()) for _ in range(self.feature_table.shape[0])]
        self.feature_table["created"] = [datetime.now() for _ in range(self.feature_table.shape[0])]
        logger.info(f"Feature Table creada -> {datetime.now()}")

       
        if external_data is not None:
            self.feature_table = pd.concat(
                [
                    self.feature_table.reset_index(drop=True),
                    external_data.reset_index(drop=True)
                ],
                axis=1
            )

        return self.feature_table


    def write_feature_table(self, filepath: str) -> None:
        if self.feature_table is not None and not self.feature_table.empty:
            self.feature_table.to_parquet(f"{filepath}.parquet", index=False)
            self.feature_table.to_csv(f"{filepath}.csv", index=False)
        else:
            raise Exception("La feature table no ha sido creada.")


f = Feast_use(filepath= '/home/marcoloq/mle2/Feature_Store_3/valued_pup/feature_repo')
feature_table_new = f.table_creator(external_data=reducing_data)
logger.info("Guardando feature table")
f.write_feature_table(filepath='/home/marcoloq/mle2/Feature_Store_3/valued_pup/feature_repo')
# Out:
# 2025-11-18 21:02:16.367 | INFO     | __main__:table_creator:19 - Feature Table creada -> 2025-11-18 21:02:16.366698
# 2025-11-18 21:02:16.372 | INFO     | __main__:<module>:44 - Guardando feature table

# %%
mlflow.set_tracking_uri('https://dagshub.com/Marquinhos9873/mle3.mlflow')

# %%
mlflow.set_experiment("Dsrp3_stresslevel")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/7e40128336844cc6bf683f7a8b437441', creation_time=1763516334271, experiment_id='2', last_update_time=1763516334271, lifecycle_stage='active', name='Dsrp3_stresslevel', tags={}>

# %%
params={"Decision Tree": {
                        "criterion": ['gini','log_loss'],
                        "max_depth": [0, 10, 12, 16],
                        "min_samples_split": [2, 3, 4, 5]
                    },
    
                     "Random Forest":{
                        "n_estimators" : [110 , 115, 125, 130],
                        "criterion" : ['gini' ,'log_loss', 'entropy'],
                        "max_depth" : [None, 5, 7 , 8]
                    },
    
                    "Gradient Boosting": {
                        "n_estimators" : [110 , 115, 125, 130],
                        "max_depth" : [None, 5, 7 , 8],
                        "learning_rate": [0.0045 , 0.01, 0.05, 0.10],
                        "min_samples_split": [2, 3, 4, 5],
                    },
                    "XGBClassifier":{
                        'learning_rate':[0.0045 , 0.01, 0.05, 0.10],
                        'max_depth': [5, 6, 7],
                        'n_estimators': [256, 128, 64, 12],
                        'tree_method': ['auto', 'approx']
                    },
    
                    "CatBoosting Classifier":{
                        'iterations': [200, 400, 800],
                        'learning_rate': [0.001, 0.01, 0.05, 0.1],
                        'depth': [3, 4, 6, 8, 10],
                        'l2_leaf_reg': [1, 3, 5, 7, 9],
                        'bootstrap_type': ['Bayesian', 'Bernoulli', 'MVS']
                    }
                    
                }

# %%
SAVE_DIR = "/home/marcoloq/mle2/data/model_metrics_local"
os.makedirs(SAVE_DIR, exist_ok=True)

# %%
xgb = XGBClassifier(device= 'cuda', verbosity = 1)

# %%
kitty = CatBoostClassifier(task_type = 'GPU', early_stopping_rounds = 100)

# %%
Forest = RandomForestClassifier(verbose = 1)

# %%
Grades = GradientBoostingClassifier(verbose = 1)

# %%
X, y
# Out:
# (      Id  Gender  Age  Have you recently experienced stress in your life?  \
#  0      1       0   20                                                  3
#  1      2       0   20                                                  2
#  2      3       0   20                                                  5
#  3      4       1   20                                                  3
#  4      5       0   20                                                  3
#  ..   ...     ...  ...                                                ...
#  838  839       0   21                                                  3
#  839  840       1   19                                                  3
#  840  841       1   19                                                  4
#  841  842       0   20                                                  5
#  842  843       0   19                                                  4
#
#       Have you noticed a rapid heartbeat or palpitations?  \
#  0                                                    4
#  1                                                    3
#  2                                                    4
#  3                                                    4
#  4                                                    3
#  ..                                                 ...
#  838                                                  4
#  839                                                  2
#  840                                                  4
#  841                                                  4
#  842                                                  3
#
#       Have you been dealing with anxiety or tension recently?  \
#  0                                                    2
#  1                                                    2
#  2                                                    2
#  3                                                    3
#  4                                                    3
#  ..                                                 ...
#  838                                                  2
#  839                                                  1
#  840                                                  3
#  841                                                  3
#  842                                                  1
#
#       Do you face any sleep problems or difficulties falling asleep?  \
#  0                                                    5
#  1                                                    1
#  2                                                    2
#  3                                                    2
#  4                                                    2
#  ..                                                 ...
#  838                                                  3
#  839                                                  2
#  840                                                  4
#  841                                                  4
#  842                                                  3
#
#       Have you been dealing with anxiety or tension recently?.1  \
#  0                                                    1
#  1                                                    1
#  2                                                    1
#  3                                                    2
#  4                                                    2
#  ..                                                 ...
#  838                                                  5
#  839                                                  2
#  840                                                  3
#  841                                                  3
#  842                                                  2
#
#       Have you been getting headaches more often than usual?  \
#  0                                                    2
#  1                                                    1
#  2                                                    3
#  3                                                    3
#  4                                                    4
#  ..                                                 ...
#  838                                                  1
#  839                                                  1
#  840                                                  2
#  841                                                  4
#  842                                                  1
#
#       Do you get irritated easily?  ...  \
#  0                               1  ...
#  1                               1  ...
#  2                               4  ...
#  3                               4  ...
#  4                               4  ...
#  ..                            ...  ...
#  838                             5  ...
#  839                             2  ...
#  840                             2  ...
#  841                             4  ...
#  842                             1  ...
#
#       Are you facing any difficulties with your professors or instructors?  \
#  0                                                    3
#  1                                                    3
#  2                                                    2
#  3                                                    1
#  4                                                    2
#  ..                                                 ...
#  838                                                  2
#  839                                                  1
#  840                                                  2
#  841                                                  2
#  842                                                  1
#
#       Is your working environment unpleasant or stressful?  \
#  0                                                    1
#  1                                                    2
#  2                                                    2
#  3                                                    1
#  4                                                    3
#  ..                                                 ...
#  838                                                  3
#  839                                                  1
#  840                                                  2
#  841                                                  2
#  842                                                  1
#
#       Do you struggle to find time for relaxation and leisure activities?  \
#  0                                                    4
#  1                                                    1
#  2                                                    2
#  3                                                    2
#  4                                                    1
#  ..                                                 ...
#  838                                                  3
#  839                                                  1
#  840                                                  2
#  841                                                  1
#  842                                                  3
#
#       Is your hostel or home environment causing you difficulties?  \
#  0                                                    1
#  1                                                    1
#  2                                                    1
#  3                                                    1
#  4                                                    2
#  ..                                                 ...
#  838                                                  3
#  839                                                  3
#  840                                                  2
#  841                                                  4
#  842                                                  1
#
#       Do you lack confidence in your academic performance?  \
#  0                                                    2
#  1                                                    3
#  2                                                    4
#  3                                                    2
#  4                                                    2
#  ..                                                 ...
#  838                                                  4
#  839                                                  2
#  840                                                  3
#  841                                                  3
#  842                                                  1
#
#       Do you lack confidence in your choice of academic subjects?  \
#  0                                                    1
#  1                                                    2
#  2                                                    1
#  3                                                    1
#  4                                                    4
#  ..                                                 ...
#  838                                                  1
#  839                                                  1
#  840                                                  1
#  841                                                  5
#  842                                                  2
#
#       Academic and extracurricular activities conflicting for you?  \
#  0                                                    3
#  1                                                    1
#  2                                                    1
#  3                                                    1
#  4                                                    2
#  ..                                                 ...
#  838                                                  2
#  839                                                  2
#  840                                                  4
#  841                                                  4
#  842                                                  2
#
#       Do you attend classes regularly?  Have you gained/lost weight?  \
#  0                                   1                             2
#  1                                   4                             2
#  2                                   2                             1
#  3                                   5                             3
#  4                                   2                             2
#  ..                                ...                           ...
#  838                                 2                             2
#  839                                 3                             1
#  840                                 5                             3
#  841                                 5                             1
#  842                                 5                             4
#
#       symptom_mean
#  0        2.208333
#  1        2.000000
#  2        2.541667
#  3        2.583333
#  4        2.500000
#  ..            ...
#  838     37.666667
#  839     36.750000
#  840     37.583333
#  841     38.125000
#  842     37.333333
#
#  [843 rows x 27 columns],
#  0      2
#  1      2
#  2      2
#  3      2
#  4      2
#        ..
#  838    2
#  839    1
#  840    2
#  841    2
#  842    2
#  Name: Which type of stress do you primarily experience?, Length: 843, dtype: int64)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size= 0.255)
logger.info("Datos divididos en train y test")
logger.info(f"Datos de train: {X_train.shape}")
logger.info(f"Datos de test: {X_test.shape}")
logger.info(f"Datos de train: {y_train.shape}")
logger.info(f"Datos de test: {y_test.shape}")
# Out:
# 2025-11-18 21:02:23.640 | INFO     | __main__:<module>:2 - Datos divididos en train y test
# 2025-11-18 21:02:23.641 | INFO     | __main__:<module>:3 - Datos de train: (628, 27)
# 2025-11-18 21:02:23.642 | INFO     | __main__:<module>:4 - Datos de test: (215, 27)
# 2025-11-18 21:02:23.642 | INFO     | __main__:<module>:5 - Datos de train: (628,)
# 2025-11-18 21:02:23.644 | INFO     | __main__:<module>:6 - Datos de test: (215,)

# %%
#StressLevel

rescaled_StressLevel  = reescalador.scaler_process(data = X, scale_method = StandardScaler(), pipeline_name = "")

pipeline, metadata = rescaled_StressLevel.run_scaler()
variance_plot = rescaled_StressLevel.plot_variance()
rescaled_StressLevel.save_and_log(variance_plot, "variance_plot_stresslevel.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 5
#       1 #StressLevel
#       3 rescaled_StressLevel  = reescalador.scaler_process(data = X, scale_method = StandardScaler())
# ----> 5 pipeline, metadata = rescaled_StressLevel.run_scaler()
#       6 variance_plot = rescaled_StressLevel.plot_variance()
#       7 rescaled_StressLevel.save_and_log(variance_plot, "variance_plot_stresslevel.png")
#
# File ~/mle2/notebooks/reescalador.py:28, in scaler_process.run_scaler(self)
#      24 transformed = scaler_pipeline.fit_transform(self.data)
#      25 self.explained_variance = self.pca.explained_variance_ratio_
#      26 metadata = pd.DataFrame(
#      27     transformed,
# ---> 28     columns=[f"{self.pipeline_name}_feat_{i+1}" for i in range(self.pca.n_components_)]
#      29 )
#      31 return scaler_pipeline, metadata
#
# AttributeError: 'scaler_process' object has no attribute 'pipeline_name'

# %%
def evaluate_classification_model(name_model: str, y_real, predictions, probabilities, save_path: str = None):
    
    
    label_map = {
        0: "No Stress",
        1: "Distress",
        2: "Eustress"
    }
    display_labels = [label_map[i] for i in sorted(label_map.keys())]

    
    cm = confusion_matrix(y_real, predictions)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)

    plt.figure(figsize=(6, 5))
    ax = plt.gca()                     
    disp.plot(cmap="Blues", values_format='d', ax=ax)
    plt.title(f"Matriz de Confusión - {name_model}")
    plt.tight_layout()

    if save_path:
        plt.savefig(f"{save_path}/{name_model}_confusion_matrix.png")

    plt.show()


    
    accuracy = accuracy_score(y_real, predictions)
    precision = precision_score(y_real, predictions, average='weighted')
    recall = recall_score(y_real, predictions, average='weighted')
    f1 = f1_score(y_real, predictions, average='weighted')

    
    try:
        auc_score = roc_auc_score(y_real, probabilities, multi_class='ovr')
    except:
        auc_score = None
        print("AUC no disponible para este modelo.")

    print(f"\n>>> Métricas del modelo: {name_model}")
    print(f"accuracy : {accuracy}")
    print(f"precision: {precision}")
    print(f"recall   : {recall}")
    print(f"f1_score : {f1}")
    print(f"auc_score: {auc_score}")

    return {
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1_score": f1,
        "auc_score": auc_score
    }

# %%
y_train
# Out:
# 90     2
# 790    2
# 181    2
# 439    2
# 479    2
#       ..
# 71     2
# 106    2
# 270    2
# 435    2
# 102    2
# Name: Which type of stress do you primarily experience?, Length: 628, dtype: int64

# %% [markdown]
# ### Entrenamiento sin Hiperparámetros

# %%
#XGBoostClassifier
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
save_path = os.path.join(project_root, "data/model_metrics_local")
mlflow.set_tracking_uri("https://dagshub.com/Marquinhos9873/mle3.mlflow")
mlflow.set_experiment("Default XGBoostClassifier")

mlflow.autolog()
with mlflow.start_run(run_name="Default XGBoostClassifier_default_params"):
    xgb.fit(X_train, y_train)
    
    predictions_xgboost_default = xgb.predict(X_test)
    probabilities_xgboost_default = xgb.predict_proba(X_test)

    metrics = evaluate_classification_model(
        name_model="XGBoostClassifier_default",
        y_real=y_test,
        predictions=predictions_xgboost_default,
        probabilities=probabilities_xgboost_default,
        save_path=save_path
    )
# Out:
# 2025/11/18 20:31:55 INFO mlflow.tracking.fluent: Experiment with name 'Default XGBoostClassifier' does not exist. Creating a new experiment.
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[18], line 5
#       3 save_path = os.path.join(project_root, "data/model_metrics_local")
#       4 mlflow.set_tracking_uri("https://dagshub.com/Marquinhos9873/mle3.mlflow")
# ----> 5 mlflow.set_experiment("Default XGBoostClassifier")
#       7 mlflow.autolog()
#       8 with mlflow.start_run(run_name="Default XGBoostClassifier_default_params"):
#
# File ~/mle2/.venv/lib/python3.12/site-packages/mlflow/tracking/fluent.py:189, in set_experiment(experiment_name, experiment_id)
#     184 _logger.info(
#     185     "Experiment with name '%s' does not exist. Creating a new experiment.",
#     186     experiment_name,
#     187 )
#     188 try:
# --> 189     experiment_id = client.create_experiment(experiment_name)
#     190 except MlflowException as e:
#     191     if e.error_code == "RESOURCE_ALREADY_EXISTS":
#     192         # NB: If two simultaneous processes attempt to set the same experiment
#     193         # simultaneously, a race condition may be encountered here wherein
#     194         # experiment creation fails
#
# File ~/mle2/.venv/lib/python3.12/site-packages/mlflow/tracking/_tracking_service/client.py:275, in TrackingServiceClient.create_experiment(self, name, artifact_location, tags)
#     261 """Create an experiment.
#     262
#     263 Args:
#    (...)    272
#     273 """
#     274 _validate_experiment_artifact_location(artifact_location)
# --> 275 return self.store.create_experiment(
#     276     name=name,
#     277     artifact_location=artifact_location,
#     278     tags=[ExperimentTag(key, value) for (key, value) in tags.items()] if tags else [],
#     279 )
#
# File ~/mle2/.venv/lib/python3.12/site-packages/mlflow/store/tracking/rest_store.py:185, in RestStore.create_experiment(self, name, artifact_location, tags)
#     181 tag_protos = [tag.to_proto() for tag in tags] if tags else []
#     182 req_body = message_to_json(
#     183     CreateExperiment(name=name, artifact_location=artifact_location, tags=tag_protos)
#     184 )
# --> 185 response_proto = self._call_endpoint(CreateExperiment, req_body)
#     186 return response_proto.experiment_id
#
# File ~/mle2/.venv/lib/python3.12/site-packages/mlflow/store/tracking/rest_store.py:134, in RestStore._call_endpoint(self, api, json_body, endpoint, retry_timeout_seconds)
#     132     endpoint, method = _METHOD_TO_INFO[api]
#     133 response_proto = api.Response()
# --> 134 return call_endpoint(
#     135     self.get_host_creds(),
#     136     endpoint,
#     137     method,
#     138     json_body,
#     139     response_proto,
#     140     retry_timeout_seconds=retry_timeout_seconds,
#     141 )
#
# File ~/mle2/.venv/lib/python3.12/site-packages/mlflow/utils/rest_utils.py:590, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers, retry_timeout_seconds)
#     587     call_kwargs["json"] = json_body
#     588     response = http_request(**call_kwargs)
# --> 590 response = verify_rest_response(response, endpoint)
#     591 response_to_parse = response.text
#     592 try:
#
# File ~/mle2/.venv/lib/python3.12/site-packages/mlflow/utils/rest_utils.py:310, in verify_rest_response(response, endpoint)
#     305     else:
#     306         base_msg = (
#     307             f"API request to endpoint {endpoint} "
#     308             f"failed with error code {response.status_code} != 200"
#     309         )
# --> 310         raise MlflowException(
#     311             f"{base_msg}. Response body: '{response.text}'",
#     312             error_code=get_error_code(response.status_code),
#     313         )
#     315 # Skip validation for endpoints (e.g. DBFS file-download API) which may return a non-JSON
#     316 # response
#     317 if endpoint.startswith(_REST_API_PATH_PREFIX) and not _can_parse_as_json_object(response.text):
#
# MlflowException: API request to endpoint /api/2.0/mlflow/experiments/create failed with error code 403 != 200. Response body: ''

# %%
#RandomForestClassifier

Forest.fit(X_train, y_train)
predictions_forest_default = Forest.predict(X_test)
probabilities_forest_default = Forest.predict_proba(X_test)
metrics = evaluate_classification_model(name_model = 'RandomForestClassifer_default', y_real = y_test, predictions = predictions_forest_default, probabilities = probabilities_forest_default, save_path = save_path)
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# AUC no disponible para este modelo.
#
# >>> Métricas del modelo: RandomForestClassifer_default
# accuracy : 0.9209302325581395
# precision: 0.8760486850684635
# recall   : 0.9209302325581395
# f1_score : 0.8865189837605387
# auc_score: None
# /home/marcoloq/mle2/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
#CatBoostClassifier

kitty.fit(X_train, y_train)
predictions_kitty_default = kitty.predict(X_test)
probabilities_kitty_default = kitty.predict_proba(X_test)
metrics = evaluate_classification_model(name_model = 'CatBoostClassifier_default', y_real = y_test, predictions = predictions_kitty_default, probabilities = probabilities_kitty_default, save_path = save_path)
# Out:
# Learning rate set to 0.059029
# 0:	learn: 1.0223135	total: 23.9ms	remaining: 23.9s
# 1:	learn: 0.9549249	total: 35.2ms	remaining: 17.6s
# 2:	learn: 0.8932017	total: 50.5ms	remaining: 16.8s
# 3:	learn: 0.8383496	total: 71.2ms	remaining: 17.7s
# 4:	learn: 0.7928439	total: 88.7ms	remaining: 17.7s
# 5:	learn: 0.7504859	total: 105ms	remaining: 17.4s
# 6:	learn: 0.7142731	total: 117ms	remaining: 16.6s
# 7:	learn: 0.6786204	total: 132ms	remaining: 16.3s
# 8:	learn: 0.6466675	total: 143ms	remaining: 15.7s
# 9:	learn: 0.6166247	total: 154ms	remaining: 15.3s
# 10:	learn: 0.5916386	total: 168ms	remaining: 15.1s
# 11:	learn: 0.5666345	total: 179ms	remaining: 14.8s
# 12:	learn: 0.5434949	total: 195ms	remaining: 14.8s
# 13:	learn: 0.5206453	total: 208ms	remaining: 14.7s
# 14:	learn: 0.5009496	total: 221ms	remaining: 14.5s
# 15:	learn: 0.4816134	total: 234ms	remaining: 14.4s
# 16:	learn: 0.4629632	total: 248ms	remaining: 14.3s
# 17:	learn: 0.4486659	total: 263ms	remaining: 14.4s
# 18:	learn: 0.4323707	total: 281ms	remaining: 14.5s
# 19:	learn: 0.4188514	total: 299ms	remaining: 14.7s
# 20:	learn: 0.4050493	total: 317ms	remaining: 14.8s
# 21:	learn: 0.3913609	total: 330ms	remaining: 14.7s
# 22:	learn: 0.3796085	total: 343ms	remaining: 14.6s
# 23:	learn: 0.3669660	total: 352ms	remaining: 14.3s
# 24:	learn: 0.3577354	total: 362ms	remaining: 14.1s
# 25:	learn: 0.3474755	total: 372ms	remaining: 13.9s
# 26:	learn: 0.3376072	total: 381ms	remaining: 13.7s
# 27:	learn: 0.3282625	total: 396ms	remaining: 13.7s
# 28:	learn: 0.3192444	total: 414ms	remaining: 13.9s
# 29:	learn: 0.3106634	total: 424ms	remaining: 13.7s
# 30:	learn: 0.3025727	total: 433ms	remaining: 13.5s
# 31:	learn: 0.2953398	total: 442ms	remaining: 13.4s
# 32:	learn: 0.2882884	total: 455ms	remaining: 13.3s
# 33:	learn: 0.2811169	total: 463ms	remaining: 13.2s
# 34:	learn: 0.2741202	total: 473ms	remaining: 13s
# 35:	learn: 0.2678887	total: 481ms	remaining: 12.9s
# 36:	learn: 0.2617562	total: 490ms	remaining: 12.8s
# 37:	learn: 0.2554746	total: 501ms	remaining: 12.7s
# 38:	learn: 0.2501776	total: 509ms	remaining: 12.5s
# 39:	learn: 0.2447434	total: 519ms	remaining: 12.4s
# 40:	learn: 0.2392362	total: 527ms	remaining: 12.3s
# 41:	learn: 0.2344000	total: 535ms	remaining: 12.2s
# 42:	learn: 0.2299849	total: 544ms	remaining: 12.1s
# 43:	learn: 0.2255614	total: 553ms	remaining: 12s
# 990:	learn: 0.0065574	total: 1m 13s	remaining: 668ms
# 991:	learn: 0.0065502	total: 1m 13s	remaining: 594ms
# 992:	learn: 0.0065399	total: 1m 13s	remaining: 520ms
# 993:	learn: 0.0065305	total: 1m 13s	remaining: 446ms
# 994:	learn: 0.0065241	total: 1m 13s	remaining: 372ms
# 995:	learn: 0.0065168	total: 1m 14s	remaining: 297ms
# 996:	learn: 0.0065067	total: 1m 14s	remaining: 223ms
# 997:	learn: 0.0064986	total: 1m 14s	remaining: 149ms
# 998:	learn: 0.0064912	total: 1m 14s	remaining: 74.4ms
# 999:	learn: 0.0064865	total: 1m 14s	remaining: 0us
# AUC no disponible para este modelo.
#
# >>> Métricas del modelo: CatBoostClassifier_default
# accuracy : 0.9395348837209302
# precision: 0.9432779623477298
# recall   : 0.9395348837209302
# f1_score : 0.9234093652698305
# auc_score: None

# %%
#CatBoostClassifier

Grades.fit(X_train, y_train)
predictions_grades_default = Grades.predict(X_test)
probabilities_grades_default = Grades.predict_proba(X_test)
metrics = evaluate_classification_model(name_model = 'GradientBoostClassifier_deafult', y_real = y_test, predictions = predictions_grades_default, probabilities = probabilities_grades_default, save_path = save_path)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           0.2889            3.78s
#          2           0.2605            2.22s
#          3           0.2413            1.68s
#          4           0.2207            1.43s
#          5           0.2029            1.26s
#          6           0.1880            1.14s
#          7           0.1758            1.06s
#          8           0.1641            0.99s
#          9           0.1543            0.94s
#         10           0.1440            0.89s
#         20           0.0781            0.67s
#         30           0.0480            0.56s
#         40           0.0312            0.46s
#         50           0.0205            0.37s
#         60           0.0143            0.29s
#         70           0.0098            0.22s
#         80           0.0070            0.15s
#         90           0.0050            0.07s
#        100           0.0036            0.00s
# AUC no disponible para este modelo.
#
# >>> Métricas del modelo: GradientBoostClassifier_deafult
# accuracy : 0.9302325581395349
# precision: 0.926124031007752
# recall   : 0.9302325581395349
# f1_score : 0.9111142220444546
# auc_score: None

# %%
mlflow.end_run()

# %% [markdown]
# ### ----------------------------------------------------------------------------------------------------------------

# %%
xgb = XGBClassifier(device= 'cuda', verbosity = 1)

# %%
kitty = CatBoostClassifier(task_type = 'GPU', devices = '0', early_stopping_rounds = 100)

# %%
Forest = RandomForestClassifier(verbose = 1)

# %%
Grades = GradientBoostingClassifier(verbose = 1)

# %%
Stress.info()

# %%
X = Stress.drop(columns=["stress_level"])
y = Stress["stress_level"]

# %%
X, y

# %%
xgb = XGBClassifier(device= 'cuda', verbosity = 1)

# %%
kitty = CatBoostClassifier(task_type = 'GPU', devices = '0', early_stopping_rounds = 100)

# %%
Grades = GradientBoostingClassifier()

# %%
Forest = RandomForestClassifier()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size= 0.255)
logger.info("Datos divididos en train y test")
logger.info(f"Datos de train: {X_train.shape}")
logger.info(f"Datos de test: {X_test.shape}")
logger.info(f"Datos de train: {y_train.shape}")
logger.info(f"Datos de test: {y_test.shape}")

# %%
#Stress
rescaled_Stress = scaler_process(
    data= X,
    scale_method=StandardScaler(),
    pipeline_name='PrimeiroPipeline'
)

pipeline, metadata = rescaled_Stress.run_scaler()
rescaled_Stress.plot_variance()

# %% [markdown]
# ### Hp ops

# %% [markdown]
# ![image.png](attachment:76a9ffe8-f982-4a32-bbbb-f5be30d7e8e4.png)
